# %%
# %pip install rfflearn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement rfflearn (from versions: none)
# ERROR: No matching distribution found for rfflearn

# %%
import numpy as np
import rfflearn.cpu as rfflearn                     # Import module
X = np.array([[-1, -1], [-2, -1], [1, 1], [2, 1]])  # Define input data
y = np.array([1, 1, 2, 2])                          # Defile label data
svc = rfflearn.RFFSVC().fit(X, y)                   # Training (on CPU)
svc.score(X, y)                                     # Inference (on CPU)

svc.predict(np.array([[-0.8, -1]]))
# Out:
# array([1])

# %%
X = np.array([[-1, -1], [-2, -1], [1, 1], [2, 1]])  # Define input data
y = np.array([1, 1, 0, 0])                          # Defile label data
svc = rfflearn.rfflearn_cpu_gp.GPC("rff").fit(X, y)                   # Training (on CPU)
svc.score(X, y)                                     # Inference (on CPU)

svc.predict(np.array([[-0.8, -1]]))
# Out:
# array([1], dtype=int64)

# %%
import site
print(site.getsitepackages())
# Out:
# ['c:\\Users\\aejog\\anaconda3', 'c:\\Users\\aejog\\anaconda3\\Lib\\site-packages']

# %%
# %pip install -r "C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt"
# Out:
# Requirement already satisfied: numpy>=1.19.0 in c:\users\aejog\anaconda3\lib\site-packages (from -r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\aejog\anaconda3\lib\site-packages (from -r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 3)) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.24.0 in c:\users\aejog\anaconda3\lib\site-packages (from -r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: torch>=1.7.0 in c:\users\aejog\anaconda3\lib\site-packages (from -r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 7)) (2.1.2)
# Collecting optuna>=2.3.0 (from -r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10))
#   Obtaining dependency information for optuna>=2.3.0 from https://files.pythonhosted.org/packages/15/da/68883911855d8b4d521f9a370e4e6aab8232b91c1d8d5a8348c4680c6642/optuna-3.6.1-py3-none-any.whl.metadata
#   Downloading optuna-3.6.1-py3-none-any.whl.metadata (17 kB)
# Collecting shap>=0.37.0 (from -r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13))
#   Obtaining dependency information for shap>=0.37.0 from https://files.pythonhosted.org/packages/82/29/923869e92c74bf07ec2b9a52ad5ac67d4184c873ba33ada7d4584356463a/shap-0.46.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading shap-0.46.0-cp311-cp311-win_amd64.whl.metadata (25 kB)
# Collecting docopt>=0.6.0 (from -r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 16))
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: joblib>=1.1.1 in c:\users\aejog\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aejog\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: filelock in c:\users\aejog\anaconda3\lib\site-packages (from torch>=1.7.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 7)) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\aejog\anaconda3\lib\site-packages (from torch>=1.7.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 7)) (4.7.1)
# Requirement already satisfied: sympy in c:\users\aejog\anaconda3\lib\site-packages (from torch>=1.7.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 7)) (1.11.1)
# Requirement already satisfied: networkx in c:\users\aejog\anaconda3\lib\site-packages (from torch>=1.7.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 7)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\aejog\anaconda3\lib\site-packages (from torch>=1.7.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\aejog\anaconda3\lib\site-packages (from torch>=1.7.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 7)) (2023.4.0)
# Collecting alembic>=1.5.0 (from optuna>=2.3.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10))
#   Obtaining dependency information for alembic>=1.5.0 from https://files.pythonhosted.org/packages/df/ed/c884465c33c25451e4a5cd4acad154c29e5341e3214e220e7f3478aa4b0d/alembic-1.13.2-py3-none-any.whl.metadata
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna>=2.3.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10))
#   Obtaining dependency information for colorlog from https://files.pythonhosted.org/packages/f3/18/3e867ab37a24fdf073c1617b9c7830e06ec270b1ea4694a624038fc40a03/colorlog-6.8.2-py3-none-any.whl.metadata
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\aejog\anaconda3\lib\site-packages (from optuna>=2.3.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10)) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\aejog\anaconda3\lib\site-packages (from optuna>=2.3.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10)) (1.4.39)
# Requirement already satisfied: tqdm in c:\users\aejog\anaconda3\lib\site-packages (from optuna>=2.3.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10)) (4.65.0)
# Requirement already satisfied: PyYAML in c:\users\aejog\anaconda3\lib\site-packages (from optuna>=2.3.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10)) (6.0)
# Requirement already satisfied: pandas in c:\users\aejog\anaconda3\lib\site-packages (from shap>=0.37.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13)) (2.0.3)
# Collecting slicer==0.0.8 (from shap>=0.37.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13))
#   Obtaining dependency information for slicer==0.0.8 from https://files.pythonhosted.org/packages/63/81/9ef641ff4e12cbcca30e54e72fb0951a2ba195d0cda0ba4100e532d929db/slicer-0.0.8-py3-none-any.whl.metadata
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in c:\users\aejog\anaconda3\lib\site-packages (from shap>=0.37.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13)) (0.57.1)
# Requirement already satisfied: cloudpickle in c:\users\aejog\anaconda3\lib\site-packages (from shap>=0.37.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13)) (2.2.1)
# Collecting Mako (from alembic>=1.5.0->optuna>=2.3.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10))
#   Obtaining dependency information for Mako from https://files.pythonhosted.org/packages/03/62/70f5a0c2dd208f9f3f2f9afd103aec42ee4d9ad2401d78342f75e9b8da36/Mako-1.3.5-py3-none-any.whl.metadata
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\aejog\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna>=2.3.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: colorama in c:\users\aejog\anaconda3\lib\site-packages (from tqdm->optuna>=2.3.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aejog\anaconda3\lib\site-packages (from jinja2->torch>=1.7.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\aejog\anaconda3\lib\site-packages (from numba->shap>=0.37.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13)) (0.40.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aejog\anaconda3\lib\site-packages (from pandas->shap>=0.37.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aejog\anaconda3\lib\site-packages (from pandas->shap>=0.37.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aejog\anaconda3\lib\site-packages (from pandas->shap>=0.37.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13)) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\aejog\anaconda3\lib\site-packages (from sympy->torch>=1.7.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\aejog\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap>=0.37.0->-r C:\Users\aejog\Documents\stage-inria\projets\random-fourier-features\requirements.txt (line 13)) (1.16.0)
# Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#    ---------------------------------------- 0.0/380.1 kB ? eta -:--:--
#    --------------------- ------------------ 204.8/380.1 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 380.1/380.1 kB 4.7 MB/s eta 0:00:00
# Downloading shap-0.46.0-cp311-cp311-win_amd64.whl (456 kB)
#    ---------------------------------------- 0.0/456.1 kB ? eta -:--:--
#    -------------------------- ------------- 307.2/456.1 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 456.1/456.1 kB 5.6 MB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/233.0 kB ? eta -:--:--
#    ---------------------------------------- 233.0/233.0 kB 4.7 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ---------------------------------------- 78.6/78.6 kB 4.6 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=7ee0d779b9a809b85deb569dfa2a88c529152d758d5c068be98086825426c6fc
#   Stored in directory: c:\users\aejog\appdata\local\pip\cache\wheels\1a\b0\8c\4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# Installing collected packages: docopt, slicer, Mako, colorlog, alembic, shap, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 docopt-0.6.2 optuna-3.6.1 shap-0.46.0 slicer-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data: a simple time series
time = np.linspace(0, 1, 500)
signal = np.sin(2 * np.pi * 50 * time) + np.sin(2 * np.pi * 120 * time)
signal += np.random.normal(0, 0.5, 500)  # Adding some noise

# Compute the FFT
fft_values = np.fft.fft(signal)

# Get the corresponding frequencies
frequencies = np.fft.fftfreq(len(signal), d=(time[1] - time[0]))

# Get the amplitude (magnitude) of the FFT values
amplitudes = np.abs(fft_values)

# Plot the original signal and its FFT
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.plot(time, signal)
plt.title('Original Signal')

plt.subplot(2, 1, 2)
plt.plot(frequencies[:len(frequencies)//2], amplitudes[:len(amplitudes)//2])  # Only plot the positive frequencies
plt.title('FFT of the Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')

plt.tight_layout()
plt.show()

# Dimensionality Reduction: Keep only the top N significant frequencies
N = 10
indices = np.argsort(amplitudes)[-N:]  # Indices of the top N amplitudes

# Create a mask to zero out the non-significant frequencies
mask = np.zeros_like(fft_values, dtype=bool)
mask[indices] = True
reduced_fft_values = fft_values * mask

# Inverse FFT to get the reduced signal (if needed)
reduced_signal = np.fft.ifft(reduced_fft_values)

# Plot the reduced signal
plt.figure(figsize=(12, 6))
plt.plot(time, reduced_signal.real)
plt.title('Reduced Signal after Inverse FFT')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data: a simple time series
time = np.linspace(0, 1, 500)
signal = np.sin(2 * np.pi * 50 * time) + np.sin(2 * np.pi * 120 * time)
signal += np.random.normal(0, 0.5, 500)  # Adding some noise

# Compute the FFT
fft_values = np.fft.fft(signal)

# Get the corresponding frequencies
frequencies = np.fft.fftfreq(len(signal), d=(time[1] - time[0]))

# Get the amplitude (magnitude) of the FFT values
amplitudes = np.abs(fft_values)

# Dimensionality Reduction: Keep only the top N significant frequencies
N = 10
indices = np.argsort(amplitudes)[-N:]  # Indices of the top N amplitudes

# Create a mask to zero out the non-significant frequencies
mask = np.zeros_like(fft_values, dtype=bool)
mask[indices] = True
reduced_fft_values = fft_values * mask

# Inverse FFT to get the reduced signal (if needed)
reduced_signal = np.fft.ifft(reduced_fft_values)

# Plot the original signal, its FFT, and the reduced signal in the same subplot
fig, ax = plt.subplots(3, 1, figsize=(12, 12))

ax[0].plot(time, signal)
ax[0].set_title('Original Signal')
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Amplitude')

ax[1].plot(frequencies[:len(frequencies)//2], amplitudes[:len(amplitudes)//2])  # Only plot the positive frequencies
ax[1].set_title('FFT of the Signal')
ax[1].set_xlabel('Frequency (Hz)')
ax[1].set_ylabel('Amplitude')

ax[2].plot(time, reduced_signal.real)
ax[2].set_title('Reduced Signal after Inverse FFT')
ax[2].set_xlabel('Time')
ax[2].set_ylabel('Amplitude')

plt.tight_layout()
plt.show()
