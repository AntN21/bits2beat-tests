# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X_df = pd.read_json('mydata-mitbih-small.json')

# %%
X_data = np.array(X_df.sample(frac=1))
Y_data = X_data[:,-1]
X_data = X_data[:,:-1]

Y_data = 2.*(Y_data > 0.) - 1

# %%
plt.plot(X_data[0,:])

# %%
import torch
from src.smk.models import SMKernelGP

# %%
X = torch.FloatTensor(X_data)

# %%
N, p = X.shape

Ntrain = int(N*0.8)
Ntest = N - Ntrain

Xtrain = X[:Ntrain]
Xtest = X[:Ntest]

# %%
T = torch.arange(0,1,1/p).unsqueeze(0).repeat_interleave(N,0)

# %%
T.shape
# Out:
# torch.Size([5000, 2000])

# %%
X.shape
# Out:
# torch.Size([5000, 2000])

# %%
smkernelgp = SMKernelGP(T,X,n_dim = p)

# %%
smkernelgp.predict(T)
# Out:
# c:\Users\aejog\anaconda3\Lib\site-packages\gpytorch\models\exact_gp.py:284: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\aejog\anaconda3\Lib\site-packages\gpytorch\models\exact_prediction_strategies.py:48, in DefaultPredictionStrategy.__init__(self, train_inputs, train_prior_dist, train_labels, likelihood, root, inv_root)
#      47 try:
# ---> 48     train_labels = train_labels.reshape(
#      49         *train_labels.shape[: -len(self.train_shape)], self._train_shape.numel()
#      50     )
#      51 except RuntimeError:
#
# RuntimeError: shape '[5000, 5000]' is invalid for input of size 10000000
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 smkernelgp.predict(T)
#
# File c:\Users\aejog\Documents\stage-inria\projets\test1\src\smk\models.py:32, in GP.predict(self, x)
#      30 self.eval()
#      31 with torch.no_grad(), gp.settings.fast_pred_var():
# ---> 32     pred = self.likelihood(self(x))
#      33     lower, upper = pred.confidence_region()
#      35 return pred.mean, lower, upper
#
# File c:\Users\aejog\anaconda3\Lib\site-packages\gpytorch\models\exact_gp.py:294, in ExactGP.__call__(self, *args, **kwargs)
#     291     train_output = super().__call__(*train_inputs, **kwargs)
#     293     # Create the prediction strategy for
# --> 294     self.prediction_strategy = prediction_strategy(
#     295         train_inputs=train_inputs,
#     296         train_prior_dist=train_output,
#     297         train_labels=self.train_targets,
#     298         likelihood=self.likelihood,
#     299     )
#     301 # Concatenate the input to the training input
#     302 full_inputs = []
#
# File c:\Users\aejog\anaconda3\Lib\site-packages\gpytorch\models\exact_prediction_strategies.py:38, in prediction_strategy(train_inputs, train_prior_dist, train_labels, likelihood)
#      36 else:
#      37     cls = DefaultPredictionStrategy
# ---> 38 return cls(train_inputs, train_prior_dist, train_labels, likelihood)
#
# File c:\Users\aejog\anaconda3\Lib\site-packages\gpytorch\kernels\kernel.py:445, in Kernel.prediction_strategy(self, train_inputs, train_prior_dist, train_labels, likelihood)
#     438 def prediction_strategy(
#     439     self,
#     440     train_inputs: Tensor,
#    (...)
#     443     likelihood: GaussianLikelihood,
#     444 ) -> exact_prediction_strategies.PredictionStrategy:
# --> 445     return exact_prediction_strategies.DefaultPredictionStrategy(
#     446         train_inputs, train_prior_dist, train_labels, likelihood
#     447     )
#
# File c:\Users\aejog\anaconda3\Lib\site-packages\gpytorch\models\exact_prediction_strategies.py:52, in DefaultPredictionStrategy.__init__(self, train_inputs, train_prior_dist, train_labels, likelihood, root, inv_root)
#      48     train_labels = train_labels.reshape(
#      49         *train_labels.shape[: -len(self.train_shape)], self._train_shape.numel()
#      50     )
#      51 except RuntimeError:
# ---> 52     raise RuntimeError(
#      53         "Flattening the training labels failed. The most common cause of this error is "
#      54         + "that the shapes of the prior mean and the training labels are mismatched. "
#      55         + "The shape of the train targets is {0}, ".format(train_labels.shape)
#      56         + "while the reported shape of the mean is {0}.".format(train_prior_dist.mean.shape)
#      57     )
#      59 self.train_inputs = train_inputs
#      60 self.train_prior_dist = train_prior_dist
#
# RuntimeError: Flattening the training labels failed. The most common cause of this error is that the shapes of the prior mean and the training labels are mismatched. The shape of the train targets is torch.Size([5000, 2000]), while the reported shape of the mean is torch.Size([5000]).

# %%
smkernelgp.likelihood(X[0])
# Out:
# Normal(loc: torch.Size([2000]), scale: torch.Size([2000]))
